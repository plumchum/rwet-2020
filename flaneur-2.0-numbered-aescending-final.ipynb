# %%
text_a = open("luster.txt").read()
text_b = open("Baudelaire.txt").read()

# %%
import sys
# !{sys.executable} -m pip install markovify
# Out:
# Requirement already satisfied: markovify in /Users/plummiewummie/opt/anaconda3/lib/python3.8/site-packages (0.8.3)
# Requirement already satisfied: unidecode in /Users/plummiewummie/opt/anaconda3/lib/python3.8/site-packages (from markovify) (1.1.1)
# WARNING: You are using pip version 20.2.4; however, version 20.3 is available.
# You should consider upgrading via the '/Users/plummiewummie/opt/anaconda3/bin/python -m pip install --upgrade pip' command.

# %%
import markovify
import random

# %%
class SentencesByChar(markovify.Text):
    def word_split(self, sentence):
        return list(sentence)
    def word_join(self, words):
        return "".join(words)

# %%
level = "char"
order = 7
output_n = 1

weights = [0.5, 0.5]

weight_1 = [0.01, 0.99]
weight_2 = [0.035, 0.965]
weight_3 = [0.06, 0.94]
weight_4 = [0.085, 0.915]
weight_5 = [0.11, 0.89]
weight_6 = [0.135, 0.865]
weight_7 = [0.16, 0.84]
weight_8 = [0.185, 0.815]
weight_9 = [0.21, 0.79]

length_limit = 280

# %% [markdown]
# # Ascending short, organic

# %%
model_cls = markovify.Text if level == "word" else SentencesByChar
gen_a = model_cls(text_a, state_size=order)
gen_b = model_cls(text_b, state_size=order)
gen_combo_1 = markovify.combine([gen_a, gen_b], weight_1)
gen_combo_2 = markovify.combine([gen_a, gen_b], weight_2)
gen_combo_3 = markovify.combine([gen_a, gen_b], weight_3)
gen_combo_4 = markovify.combine([gen_a, gen_b], weight_4)
gen_combo_5 = markovify.combine([gen_a, gen_b], weight_5)
gen_combo_6 = markovify.combine([gen_a, gen_b], weight_6)
gen_combo_7 = markovify.combine([gen_a, gen_b], weight_7)
gen_combo_8 = markovify.combine([gen_a, gen_b], weight_8)
gen_combo_9 = markovify.combine([gen_a, gen_b], weight_9)
for i in range(output_n):
    spacing = ""
    spacing += "1857"
    spacing += "\n"
    spacing += "\n\n"
    spacing += " " + "1 " + gen_combo_1.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "    " + "2 " + gen_combo_2.make_short_sentence(50)
    spacing += "\n"  
    spacing += "\n\n"
    spacing += "        " + "3 " + gen_combo_3.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "             " + "4 " + gen_combo_4.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "                " + "5 " + gen_combo_5.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "                   " + "6 " + gen_combo_6.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "                       " + "7 " + gen_combo_7.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "                           " + "8 " + gen_combo_8.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "                              " + "9 " + gen_combo_9.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n" 
    spacing += "                                                                                                             2020"

print(spacing)
# Out:
# 1857
#
#
#  1 Agile and wan.
#
#
#     2 Let's, like a pall.
#
#
#         3 I want to know I walk on his cock.
#
#
#              4 When we move him.
#
#
#                 5 She inspecting my bathroom and blank.
#
#
#                    6 I look back again.
#
#
#                        7 The neighbor, and for the station twice my age.
#
#
#                            8 I think she is alone with Eric.
#
#
#                               9 “Maybe my life, with me.
#
#
#                                                                                                              2020

# %% [markdown]
# # Descending short, for curation

# %%
model_cls = markovify.Text if level == "word" else SentencesByChar
gen_a = model_cls(text_a, state_size=order)
gen_b = model_cls(text_b, state_size=order)
gen_combo_1 = markovify.combine([gen_a, gen_b], weight_1)
gen_combo_2 = markovify.combine([gen_a, gen_b], weight_2)
gen_combo_3 = markovify.combine([gen_a, gen_b], weight_3)
gen_combo_4 = markovify.combine([gen_a, gen_b], weight_4)
gen_combo_5 = markovify.combine([gen_a, gen_b], weight_5)
gen_combo_6 = markovify.combine([gen_a, gen_b], weight_6)
gen_combo_7 = markovify.combine([gen_a, gen_b], weight_7)
gen_combo_8 = markovify.combine([gen_a, gen_b], weight_8)
gen_combo_9 = markovify.combine([gen_a, gen_b], weight_9)
for i in range(output_n):
    spacing = ""
    spacing += "1857"
    spacing += "\n"
    spacing += "\n\n"
    spacing += " " + "9 " + gen_combo_9.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "    " + "8 " + gen_combo_8.make_short_sentence(50)
    spacing += "\n"  
    spacing += "\n\n"
    spacing += "        " + "7 " + gen_combo_7.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "             " + "6 " + gen_combo_6.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "                " + "5 " + gen_combo_5.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "                   " + "4 " + gen_combo_4.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "                       " + "3 " + gen_combo_3.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "                           " + "2 " + gen_combo_2.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "                              " + "1 " + gen_combo_1.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n" 
    spacing += "                                                                                                             2020"

print(spacing)
# Out:
# 1857
#
#
#  9 It is a private, but my hands.
#
#
#     8 I take the purest of her goal.
#
#
#         7 There, and sighs!
#
#
#              6 We were my hand.
#
#
#                 5 I mix thirteen years.”
#
#
#                    4 He rolls up behind.
#
#
#                        3 She is either of MF Doom.
#
#
#                            2 Sadness rises supreme?
#
#
#                               1 Autumn nights, I am.
#
#
#                                                                                                              2020

# %%
model_cls = markovify.Text if level == "word" else SentencesByChar
gen_a = model_cls(text_a, state_size=order)
gen_b = model_cls(text_b, state_size=order)
gen_combo_1 = markovify.combine([gen_a, gen_b], weight_1)
gen_combo_2 = markovify.combine([gen_a, gen_b], weight_2)
gen_combo_3 = markovify.combine([gen_a, gen_b], weight_3)
gen_combo_4 = markovify.combine([gen_a, gen_b], weight_4)
gen_combo_5 = markovify.combine([gen_a, gen_b], weight_5)
gen_combo_6 = markovify.combine([gen_a, gen_b], weight_6)
gen_combo_7 = markovify.combine([gen_a, gen_b], weight_7)
gen_combo_8 = markovify.combine([gen_a, gen_b], weight_8)
gen_combo_9 = markovify.combine([gen_a, gen_b], weight_9)
for i in range(output_n):
    spacing = ""
    spacing += "1857"
    spacing += "\n"
    spacing += "\n\n"
    spacing += " " + "9 " + gen_combo_9.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "    " + "8 " + gen_combo_8.make_short_sentence(50)
    spacing += "\n"  
    spacing += "\n\n"
    spacing += "        " + "7 " + gen_combo_7.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "             " + "6 " + gen_combo_6.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "                " + "5 " + gen_combo_5.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "                   " + "4 " + gen_combo_4.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "                       " + "3 " + gen_combo_3.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "                           " + "2 " + gen_combo_2.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "                              " + "1 " + gen_combo_1.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n" 
    spacing += "                                                                                                             2020"

print(spacing)
# Out:
# 1857
#
#
#  9 Members from trying into the risk.
#
#
#     8 I know you do mean?”
#
#
#         7 “What do you know!
#
#
#              6 Eric emptied early.
#
#
#                 5 I leave my job,” she says.
#
#
#                    4 Oh misery, in the cabbage soup.
#
#
#                        3 The idea that she is destroys.
#
#
#                            2 There, all of the azure hive?
#
#
#                               1 My soul, more profound.
#
#
#                                                                                                              2020

# %%
model_cls = markovify.Text if level == "word" else SentencesByChar
gen_a = model_cls(text_a, state_size=order)
gen_b = model_cls(text_b, state_size=order)
gen_combo_1 = markovify.combine([gen_a, gen_b], weight_1)
gen_combo_2 = markovify.combine([gen_a, gen_b], weight_2)
gen_combo_3 = markovify.combine([gen_a, gen_b], weight_3)
gen_combo_4 = markovify.combine([gen_a, gen_b], weight_4)
gen_combo_5 = markovify.combine([gen_a, gen_b], weight_5)
gen_combo_6 = markovify.combine([gen_a, gen_b], weight_6)
gen_combo_7 = markovify.combine([gen_a, gen_b], weight_7)
gen_combo_8 = markovify.combine([gen_a, gen_b], weight_8)
gen_combo_9 = markovify.combine([gen_a, gen_b], weight_9)
for i in range(output_n):
    spacing = ""
    spacing += "1857"
    spacing += "\n"
    spacing += "\n\n"
    spacing += " " + "9 " + gen_combo_9.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "    " + "8 " + gen_combo_8.make_short_sentence(50)
    spacing += "\n"  
    spacing += "\n\n"
    spacing += "        " + "7 " + gen_combo_7.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "             " + "6 " + gen_combo_6.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "                " + "5 " + gen_combo_5.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "                   " + "4 " + gen_combo_4.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "                       " + "3 " + gen_combo_3.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "                           " + "2 " + gen_combo_2.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "                              " + "1 " + gen_combo_1.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n" 
    spacing += "                                                                                                             2020"

print(spacing)
# Out:
# 1857
#
#
#  9 Aroma--causing to make fire.
#
#
#     8 I ask, mostly he just as an eye.
#
#
#         7 When she wave of head cold.
#
#
#              6 “Does Eric during this time.
#
#
#                 5 I go to the house.
#
#
#                    4 Eventually clear.
#
#
#                        3 There is a farewell.
#
#
#                            2 I wish, as the nights!
#
#
#                               1 I didn’t ask why he is coming.
#
#
#                                                                                                              2020

# %%
model_cls = markovify.Text if level == "word" else SentencesByChar
gen_a = model_cls(text_a, state_size=order)
gen_b = model_cls(text_b, state_size=order)
gen_combo_1 = markovify.combine([gen_a, gen_b], weight_1)
gen_combo_2 = markovify.combine([gen_a, gen_b], weight_2)
gen_combo_3 = markovify.combine([gen_a, gen_b], weight_3)
gen_combo_4 = markovify.combine([gen_a, gen_b], weight_4)
gen_combo_5 = markovify.combine([gen_a, gen_b], weight_5)
gen_combo_6 = markovify.combine([gen_a, gen_b], weight_6)
gen_combo_7 = markovify.combine([gen_a, gen_b], weight_7)
gen_combo_8 = markovify.combine([gen_a, gen_b], weight_8)
gen_combo_9 = markovify.combine([gen_a, gen_b], weight_9)
for i in range(output_n):
    spacing = ""
    spacing += "1857"
    spacing += "\n"
    spacing += "\n\n"
    spacing += " " + "9 " + gen_combo_9.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "    " + "8 " + gen_combo_8.make_short_sentence(50)
    spacing += "\n"  
    spacing += "\n\n"
    spacing += "        " + "7 " + gen_combo_7.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "             " + "6 " + gen_combo_6.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "                " + "5 " + gen_combo_5.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "                   " + "4 " + gen_combo_4.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "                       " + "3 " + gen_combo_3.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "                           " + "2 " + gen_combo_2.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "                              " + "1 " + gen_combo_1.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n" 
    spacing += "                                                                                                             2020"

print(spacing)
# Out:
# 1857
#
#
#  9 He tells me into shadow.
#
#
#     8 I take the polymer toys, that swarms.
#
#
#         7 But today it was a very chaste.
#
#
#              6 “It’s not a chasm drawn.
#
#
#                 5 I realize that swarms.
#
#
#                    4 Sadness rises supreme?
#
#
#                        3 There is not unusually I can be a butter overhead.
#
#
#                            2 The dojang is so specifically?”
#
#
#                               1 But the golden sheaf?
#
#
#                                                                                                              2020
