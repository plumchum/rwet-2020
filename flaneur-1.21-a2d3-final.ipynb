# %%
text_a = open("luster.txt").read()
text_b = open("Baudelaire.txt").read()

# %%
import sys
# !{sys.executable} -m pip install markovify
# Out:
# Requirement already satisfied: markovify in /Users/plummiewummie/opt/anaconda3/lib/python3.8/site-packages (0.8.3)
# Requirement already satisfied: unidecode in /Users/plummiewummie/opt/anaconda3/lib/python3.8/site-packages (from markovify) (1.1.1)
# WARNING: You are using pip version 20.2.4; however, version 20.3 is available.
# You should consider upgrading via the '/Users/plummiewummie/opt/anaconda3/bin/python -m pip install --upgrade pip' command.

# %%
import markovify

# %%
generator_a = markovify.Text(text_a)
generator_b = markovify.Text(text_b)

# %%
class SentencesByChar(markovify.Text):
    def word_split(self, sentence):
        return list(sentence)
    def word_join(self, words):
        return "".join(words)

# %%
con_model = SentencesByChar("condescendences", state_size=2)

# %%
gen_a_char = SentencesByChar(text_a, state_size=10)

# %%
gen_b_char = SentencesByChar(text_b, state_size=10)

# %%
generator_a = markovify.Text(text_a)
generator_b = markovify.Text(text_b)
combo_1 = markovify.combine([generator_a, generator_b], [0.01, 0.99])
combo_2 = markovify.combine([generator_a, generator_b], [0.06, 0.94])
combo_3 = markovify.combine([generator_a, generator_b], [0.11, 0.89])
combo_4 = markovify.combine([generator_a, generator_b], [0.16, 0.84])
combo_5 = markovify.combine([generator_a, generator_b], [0.21, 0.79])

# %% [markdown]
# # Aescending 2

# %%
for i in range(15):
    print(combo_1.make_sentence())
    print() 
for i in range(1):
    print("*************")
    print()
    
for i in range(15):
    print(combo_2.make_sentence())
    print()
for i in range(1):
    print("*************")
    print()
    
for i in range(15):
    print(combo_3.make_sentence())
    print()
for i in range(1):
    print("*************")
    print()
    
for i in range(15):
    print(combo_4.make_sentence())
    print()
for i in range(1):
    print("*************")
    print()
    
for i in range(15):
    print(combo_5.make_sentence())
    print()
for i in range(1):
    print("*************")
    print()
# Out:
# The shadows of Night-time grew dense like a ruddy peach, Is ripe--like her body fair, For powerless mortals to define In notes the many concords there.
#
# The shadows of Night-time grew dense like a useless star eternally, The sterile woman's frigid majesty.
#
# She plays the game has started, Eric turns to look at me.
#
# Beauty I am seven years removed from his heart to tear, And make on him the trial of their fires Across the twin mirrors of our climes As your pale shadows--nothing is so sweet, Unless it be, on a sock before a shoe.
#
# A melancholy waltz--and a drowsiness divine, The skies like a surging wave, The naked purpled breasts of his battle array.
#
# How vast were the heavens! and the horrors of gloom; The devil had used them for his arrows a prey, I know where they keep the conversation light, even though the beater looks a little more?”
#
# And like a monkey could do this, and in their arms.
#
# Someone forgot to take after my mother.
#
# Somehow, I also wish I had inherited her ugly, glottal laugh, and encouraged me to hold back her hair.
#
# I do my due diligence,” I say, but I am not.
#
# “Listen, I have packed all my senses blent in one!
#
# Sometimes the sex to be absurd, an em dash, the Freon and wild cherry at the feet of a window while trying to put on “In the app it said Becky Abramov.”
#
# Invitation to a closet with a serpent's moist embrace, I'll crawl around thy resting-place.
#
# There, all is gold, and steel, and gems, and light, There shines, undiscovered, the gems of a strange decree, Within the sotted beast an Angel wakes.
#
# I wish, as the tomb, And delicate plants on the other room.
#
# *************
#
# Eric and I look through my neighborhood, and when I see the old woman’s face.
#
# I buy a Snapple and small and slightly outside of time.
#
# Of course, it is not his wife calls him and think for a proofreading position at a Wyndham in Teaneck and I lose my nerve.
#
# But it is here, An atmosphere sombre, envelopes the town, To some extent I’ve had a cane and a piece inspired by an Angel wakes.
#
# Within his retreat, Foreboding, Love seeks for his steeds of Doom, Could he alone have bent their pride to slavery.
#
# Does that make the contact tenuous and inexact, kisses spoiled by fervor, full of insults and of Ecstasy, They search for silence and the New York between 1975 and 2018.
#
# I want company, but that one of her now that she’s looking directly at me, but there is no sun.
#
# A black child in the business of trying to parse the irregularity of the door.
#
# This potential cruelty is so keen, so uncomfortable to watch, the indulgence so close to the true land of gain, By the time we make our way out for work.
#
# “I’m sorry I said that God was dead.
#
# I stress my editorial involvement, though the heart aspired, Art is long and Time is swift.
#
# He believed in the dark and indulge all the packing peanuts around us frothy and homogeneous, white men relieved by the beasts!
#
# She is all a little mean, but her serenity bothers me.
#
# Inside the convention center and tells me to put out a stack of someone’s belly button, but after fifteen minutes I don’t know what he thought the movie I had gotten the gist of it in the magazine and tugged the slide.
#
# “Fine,” he says, and I send my social security number to an office slut.
#
# *************
#
# Women look over my head.
#
# Obviously, I don’t let Dr. King down, I suddenly feel that she doesn’t want to take it back.
#
# Underneath ABBA, Suzanne Somers emerged from the deli across the street and see how it’s coming along.
#
# Wherein there is a prompt that asks if I have a pussy, and that she is a beautiful machine but within this tress of hair, I'll wave it in the flesh, I find myself hoping she is undressed, I still feel the recognition of some magic Minturne?
#
# Then they bring out the garbage and then exits without another word.
#
# Kieran from bodice rippers taking me out of my isolation.
#
# For a week we would eat only holds if they can be expected to act like myself.
#
# I consider what I meant when I realize Special Collections is in the center of this inclination compared to his judgment.
#
# The fluorescents wash him out, but on the most damning ones, paintings I went inside, it smelled bad and she was, for two days, too depressed to eat, but within this tress of hair, I'll wave it in my mouth.
#
# The receptionist is an old-school douche bag that is laved-- The mystical fuel which vigour imparts?
#
# Yea, light up thine eyes at the wheel and continue on.
#
# Bertha's Eyes The loveliest eyes you can practically smell the rot.
#
# I am good, but too upset by Akila’s room is owned, each square foot considered and likely free of mice.
#
# This bitter glee Of vanquished mortals, full of shouts, at times fly away?
#
# I call reception and an abortion, though on some horrific precipice in her world to implore, I would even go to the white schoolteacher who selflessly teaches her how to call forth those moments so dear.
#
# *************
#
# In the next store, she does not absorb the illegality and it was apparent he was holding my hand, I think about all the arms of his party.
#
# I put on a hot comb to the end of DeKalb and it is almost imperceptible, due in great detail, to a Sears associate about all-terrain tires, I buy a Snapple and small bottle of vodka I stole from the station, and when we reach the most inaccessible parts of my Life! wrap thyself up in some lewd music hall, Where the suns on those hot, autumn nights!
#
# Those perfumes, those infinite kisses and sighs, Are they born in some gulf to our room, we are going, so I head downstairs to gather myself, but because I have come to the hot and silent sea; Strong tresses bear me, be to me some gnocchi alla vodka on the cake and forces it into his lap and apologizing about the ring, and they are unlikely to miss.
#
# However, I am still alive, and actually this is the cat turns five and realizes it is, in fact, I feel suckered into admitting it, that like Akila and Rebecca in the afternoon is gone.
#
# “I just like a leopard might be a heart, a fist, and a different tack.
#
# Cats All ardent lovers and all the candle lights; And thus thy spectre like the way it is she always there to supply a factoid that no one knew about people, and Rebecca’s mystifying choice of song and the vast, And yet, like Ovid--I'll not mourn-- Who from his and shutting the car and remains like this as she has stuck with eleven kids in my bread.
#
# There were asylums, there was somehow still a Superman, a deadened Übermensch who imposes his idea of death it forbodes; While an odour of graves through the darkness thine eyes I divined, And I hate every movement, displacing the lines, And never I weep and never I weep and degrade.
#
# I remind myself of this interruption to his part, As he goes, sword in hand, up the weather report.
#
# I do not expect this fan fiction to become about how much he enjoyed Atlas Shrugged.
#
# She looks at me or the neighbor’s dog.
#
# When I go with her, even though, weirdly, I was pretending not to worry about me?”
#
# I leave a note on the family computer, and then exits without another word.
#
# The subjects are really having.
#
# I’m excited to hear the baying.
#
# The viol vibrates like the others—the ecstatic rutting and cushy ether of the room, to the convention center and lift the barbell as many times as I slip off my headset, and at her face and says the first night we all dutifully echo back.
#
# *************
#
# She pushes a clove of garlic in front of her dress, A stately woman passed by with hurrying feet.
#
# And even though I don’t respond because I would have loved, and _that_ you know!
#
# Between pictures of different items around the empty cup.
#
# “What does it again, though the quality is on the sweatpants and ushers them into her next pose, I realize she is moving him to sit down.
#
# The Broken Bell How sweet and keep going until I see no sign of definition before I turn my head, her truck is still the business of replacing the vinyl bracketing the lyric and unresolved brass.
#
# I feel in my purse.
#
# Traffic and avian chatter and wind in the middle, with a shipment of acetate film.
#
# The Broken Bell How sweet and keep silent, my heart, the beasts devoured--seek it not!
#
# Eric and I know and love, though there is still rotting and the optics are not complex.
#
# There is a natural mimic whose classical training was just a little lopsided, a small twenty-four-hour garage, the stars defer, and you are spared from trying to look at the office dog.
#
# From all transgressions, from all eternity, And nought bedecks the walls of the crows with their vampire bills To devour every bit of my face.
#
# She sucks the burned finger and says it’s a martini.
#
# As I wrap the scarf, I am for the night, and behold it is not how I look, nor have I ever, even though I am getting the mail such a sobering shift from the city with the broccoli smell my roommate leave, the idea of someone out there wondering if I’m not a chasm less drear.
#
# There are co-instructors wandering around, and for a moment I consider other men.
#
# The billows, in rolling depictured the skies, That first have been dying en masse, and when I get dressed and tell me that I be-- I dwell and search its depths from all snares, they save, Towards the Heavens where he sees the source, he seems relieved.
#
# *************

# %%
generator_a = markovify.Text(text_a)
generator_b = markovify.Text(text_b)
combo_1 = markovify.combine([generator_a, generator_b], [0.05, 0.95])
combo_2 = markovify.combine([generator_a, generator_b], [0.08, 0.92])
combo_3 = markovify.combine([generator_a, generator_b], [0.11, 0.89])
combo_4 = markovify.combine([generator_a, generator_b], [0.14, 0.86])
combo_5 = markovify.combine([generator_a, generator_b], [0.17, 0.83])

# %% [markdown]
# # Descending 3

# %%
for i in range(15):
    print(combo_5.make_sentence())
    print() 
for i in range(1):
    print("*************")
    print()
    
for i in range(15):
    print(combo_4.make_sentence())
    print()
for i in range(1):
    print("*************")
    print()
    
for i in range(15):
    print(combo_3.make_sentence())
    print()
for i in range(1):
    print("*************")
    print()
    
for i in range(15):
    print(combo_2.make_sentence())
    print()
for i in range(1):
    print("*************")
    print()
    
for i in range(15):
    print(combo_1.make_sentence())
    print()
for i in range(1):
    print("*************")
    print()
# Out:
# All of them are indolent, stern and wise.
#
# * * * * * * Having already been in Jersey too long.
#
# And others like unto two glowing coals, Reflecting the twofold light of the party who is good, but not good enough, which is her passive-aggressive way of making women feel heard.
#
# A lightbulb, a dinner plate, a single pivot, like an emergency.
#
# Whose glance has so suddenly caused me to call out of the pictures, I can tell Towards that Infinite I love, but never saw.
#
# “Is there anything that qualifies as a black woman who was killed on the theremin.
#
# “It’s going to miss this when I see there are nerves.
#
# There were plenty of reasons not to be extra towels and suggests that I want him.
#
# I turn and put it on the door and pulled me inside.
#
# I didn’t understand it was presumptuous to leave a note that says kill yourself, nigger bitch.
#
# The Broken Bell How sweet and keep silent, my heart, which is a premature ejaculation and it is red all the way is playing “Mary Had a Little Lamb” on the TV on low during the night I shed all my soul, this living torch obeys.
#
# With the gnawing Ideal, upon the debauchee, By the banks and society, which was a gifted pianist with double-jointed fingers, a natural black girl, bright and kind, and so vast, Like thee! oh unending Night, and thy throbs, My spirit finds them in paint.
#
# * * * Akila is much more agreeable.
#
# * * So I do a quick graphite study of my serial embarrassment, which Rebecca accommodates with a sphinx of old, Where all that and I watch him, count the seconds during which his eyes sweep over me your enchanting darkness let flow.
#
# Yea, does thy semblance, not alone for me to a place to plug it in.
#
# *************
#
# When I climb the stairs and out of the vine-kissed portico.
#
# I return to find that she used to the flame, Akila summons Uhura, practices words in Tamarian, Ferengi, and, of course, there is an extremely nosy group of surly Elmhurst Slavs putting my stuff out on him.
#
# I grab her arm above her head must feel.
#
# All of them are her.
#
# Thirty pages in, a duke, the black sheep of a portraiture, I say--How beautiful she is! how strangely rich!
#
# I press my face into the towel around her quest to find that it often throws the door to the East, Oh, hearken Beloved, how the Night softly treads!
#
# When he ends the call, we share now whittled down to my stomach, the lawn mower and the sweet Peppa Pig brand I prefer.
#
# And then we move around each other respond.
#
# Have you seen Théroigne, of the afternoon when he is very prepared, which is like I haven’t yet brushed my teeth.
#
# I close the door.
#
# The guests begin talking only to find adequate psychotherapy.
#
# “Because you are deliberate, thankful for what she looks soluble, her inertia fevered, Victorian.
#
# I open the glove compartment and asks me to go to the fridge.
#
# I saw during that first time, a voice say, Tonight only, before we climb the stairs in scrubs and rubber boots.
#
# I can’t tell if it was a word she said so much romantic as it rises supreme, Like an explosion at the paper.
#
# *************
#
# You have to endure my attempt to create art.
#
# How distant you seem to slumber deep in a month, and he doesn’t appear to be unable to get her a light sedative.
#
# All those that he likes, some supermarket standard that was big in the mirror and taps a cigarette out of his head, but as I pity you, For your unsatiated thirsts and anguished sighs, And for the rest of the time we set our first date truly went well, or some indication that he would cherish shrink from chaos vast and etern, Essay the wreaths of their Austerity.
#
# After the first time I don’t attempt to break it, though the drawing optimistically, but I hear it in the ruins of Pompeii—and everything fermenting underneath, the sagging garbage in Manhattan.
#
# And gently balanced on the lights, I am obsolete.
#
# We wore plain, shapeless clothes and have a draft, it has taken me to languish so.
#
# Or kindle desire by the fresh fecal evidence of hungry bears, Eric finds his mortality and soft cheese has become so complicated that Eric’s laughter, which is to be a text from Eric accompanied by a size or two.
#
# I can’t get the pickles down in the silence, much like the wailing of souls that mock Reality with remorseless sneers, O saints and satyrs, searchers for infinitude!
#
# I want to feel her eyes.
#
# He smiles, this small action is to wash my hair, I remember what I assume it will be born just to die.
#
# In a way that same white lady is watching from the happy family comes in and runs her fingers through my hair.
#
# I think of the shower, the water brown, more grass than seems possible that the driveway itself is ugly.
#
# “I let Pradeep go,” she says with no arms, a small twenty-four-hour garage, the stars are coming out.
#
# I start with the door and motions for me and tells me that they have noticed sooner that some men and women in the middle of whisking her matcha and says that some things should not be black.
#
# Interior Life A long while I stand in the middle of my spirit ye proclaim, O stars--no sun can ever kill your flame!
#
# *************
#
# Someone has left me with delight, If aught deludes I can unzip my skin suit and show him all the arms of his clothes.
#
# Condemned Women Like thoughtful cattle on the radicalism of the town.
#
# Far from mattock and from merriment; The man allured by a charm obscure, Here where the trees and luscious fruit; And with men whose bodies are slim and astute, And with a dog who is holding a stack of books.
#
# Posthumous Remorse Ah, when thou shalt slumber, my darkling love, Beneath a black woman at work she is moving him to sit on a hot afternoon, The scent of thy breath--oh sweetness, oh gall, And thy feet in my pregnancy-induced insomnia, when I don’t even have a secret.
#
# A conversation that is proud to say something before I climb the mountain, Akila says this explicitly as we develop this careful, mundane language, it becomes hilarious, and then left the TV turned on.
#
# Ye resemble so closely those caves in the bowers, But the god, who eludes me, I chase all in common.
#
# He was a time when you could not hope to find, one link in a jargon I don’t hear him until the room darkens, her face flushed and mean.
#
# Because in the eighties, and I have optimistically kept a bag of waffle fries and doesn’t tip.
#
# Most of the party so homogeneous it gives me pause, but that I would ask of the vine-kissed portico.
#
# Thy look containeth both the dawn and fill a bowl of cornflakes.
#
# Once, in Hoboken, we discovered a single word of condolence, smoking her cigarette and I am ashamed.
#
# I take a bus to Garden State Plaza, and I head into the fitting room, my mother in a corner seat who keeps finding nothing, which gives me pause, but that for a ravenous fast-food crowd.
#
# I follow her gaze to the entrance, I notice how incongruously this degree of difference, everything I could have this feeling, which is sear, For all save the rude and simple way.
#
# What they say that she is also the only sensation is the first.
#
# Sodium hydroxide and the worthless one; Beloved or sister--unto me the aux cord and I don’t want to have not had much success with men.
#
# *************
#
# She leans down and my hand.
#
# My soul is a precarious collection of vinyl I have made the pose demanding on purpose, but as we pass the remote.
#
# It appears on my lips morose, The poignant memory of its savage ungovernable moan.
#
# During that week, there was a time when you asked if I live in the room is hotter than the homeless man who circles the room, the lights are low, and there is even the slightest possibility of sex, because it is already giving way.
#
# So long thine eyes, thy smile, to me the thankless and the lone.
#
# I have over her head, an umbrella stripped and inverted like an incense urn, And sounds and scents in the short time it took him, on average, forty-three minutes to spare.
#
# Better than I would ask of the infuriated mob that swarms.
#
# I had money for two months.
#
# He saw that the dissonance is finally dawning on him the trial of their faded Past to entwine, The sunset drowns within its blood-red brine.
#
# In days when Christian seeds bloomed o'er the sandy waste, That seem to be, perfumed Elysian fields!
#
# I close it quickly, glance at each other respond.
#
# A mighty memory, royal and commanding tower, A garland: and her heart, bruised like a long winding-sheet dragged to the suburban quiet, the languor of thy breath--oh sweetness, oh gall, And thy feet in my bathroom bound in twine, the want ads that appear in his hands and inspects her palms.
#
# Yet sadness rises in me like a veil!
#
# Yea, art thou not an error; this is something of a sky overcast!
#
# And gently balanced on the back of wine and the neighbor who, for the surprise.
#
# *************
