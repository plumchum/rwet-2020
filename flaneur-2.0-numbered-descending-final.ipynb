# %%
text_a = open("luster.txt").read()
text_b = open("Baudelaire.txt").read()

# %%
import sys
# !{sys.executable} -m pip install markovify
# Out:
# Requirement already satisfied: markovify in /Users/plummiewummie/opt/anaconda3/lib/python3.8/site-packages (0.8.3)
# Requirement already satisfied: unidecode in /Users/plummiewummie/opt/anaconda3/lib/python3.8/site-packages (from markovify) (1.1.1)
# WARNING: You are using pip version 20.2.4; however, version 20.3 is available.
# You should consider upgrading via the '/Users/plummiewummie/opt/anaconda3/bin/python -m pip install --upgrade pip' command.

# %%
import markovify
import random

# %%
class SentencesByChar(markovify.Text):
    def word_split(self, sentence):
        return list(sentence)
    def word_join(self, words):
        return "".join(words)

# %%
level = "char"
order = 7
output_n = 1

weights = [0.5, 0.5]

weight_1 = [0.01, 0.99]
weight_2 = [0.035, 0.965]
weight_3 = [0.06, 0.94]
weight_4 = [0.085, 0.915]
weight_5 = [0.11, 0.89]
weight_6 = [0.135, 0.865]
weight_7 = [0.16, 0.84]
weight_8 = [0.185, 0.815]
weight_9 = [0.21, 0.79]

length_limit = 280

# %% [markdown]
# # Descending short, for curation

# %%
model_cls = markovify.Text if level == "word" else SentencesByChar
gen_a = model_cls(text_a, state_size=order)
gen_b = model_cls(text_b, state_size=order)
gen_combo_1 = markovify.combine([gen_a, gen_b], weight_1)
gen_combo_2 = markovify.combine([gen_a, gen_b], weight_2)
gen_combo_3 = markovify.combine([gen_a, gen_b], weight_3)
gen_combo_4 = markovify.combine([gen_a, gen_b], weight_4)
gen_combo_5 = markovify.combine([gen_a, gen_b], weight_5)
gen_combo_6 = markovify.combine([gen_a, gen_b], weight_6)
gen_combo_7 = markovify.combine([gen_a, gen_b], weight_7)
gen_combo_8 = markovify.combine([gen_a, gen_b], weight_8)
gen_combo_9 = markovify.combine([gen_a, gen_b], weight_9)
for i in range(output_n):
    spacing = ""
    spacing += "2020"
    spacing += "\n"
    spacing += "\n\n"
    spacing += " " + "9 " + gen_combo_9.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "    " + "8 " + gen_combo_8.make_short_sentence(50)
    spacing += "\n"  
    spacing += "\n\n"
    spacing += "        " + "7 " + gen_combo_7.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "             " + "6 " + gen_combo_6.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "                " + "5 " + gen_combo_5.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "                   " + "4 " + gen_combo_4.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "                       " + "3 " + gen_combo_3.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "                           " + "2 " + gen_combo_2.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "                              " + "1 " + gen_combo_1.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n" 
    spacing += "                                                                                                             1857"

print(spacing)
# Out:
# 2020
#
#
#  9 At the time I paint.
#
#
#     8 On her face is sweet,
#    In thy life is o'er!
#
#
#         7 I look on his fingers.
#
#
#              6 And, of course I am in.
#
#
#                 5 I wore this dark pit.
#
#
#                    4 I see how a starfish.
#
#
#                        3 “What does me ill.
#
#
#                            2 The Wine of memory, royal stairs?
#
#
#                               1 The smoking at all.
#
#
#                                                                                                              1857

# %%
model_cls = markovify.Text if level == "word" else SentencesByChar
gen_a = model_cls(text_a, state_size=order)
gen_b = model_cls(text_b, state_size=order)
gen_combo_1 = markovify.combine([gen_a, gen_b], weight_1)
gen_combo_2 = markovify.combine([gen_a, gen_b], weight_2)
gen_combo_3 = markovify.combine([gen_a, gen_b], weight_3)
gen_combo_4 = markovify.combine([gen_a, gen_b], weight_4)
gen_combo_5 = markovify.combine([gen_a, gen_b], weight_5)
gen_combo_6 = markovify.combine([gen_a, gen_b], weight_6)
gen_combo_7 = markovify.combine([gen_a, gen_b], weight_7)
gen_combo_8 = markovify.combine([gen_a, gen_b], weight_8)
gen_combo_9 = markovify.combine([gen_a, gen_b], weight_9)
for i in range(output_n):
    spacing = ""
    spacing += "2020"
    spacing += "\n"
    spacing += "\n\n"
    spacing += " " + "9 " + gen_combo_9.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "    " + "8 " + gen_combo_8.make_short_sentence(50)
    spacing += "\n"  
    spacing += "\n\n"
    spacing += "        " + "7 " + gen_combo_7.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "             " + "6 " + gen_combo_6.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "                " + "5 " + gen_combo_5.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "                   " + "4 " + gen_combo_4.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "                       " + "3 " + gen_combo_3.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "                           " + "2 " + gen_combo_2.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "                              " + "1 " + gen_combo_1.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n" 
    spacing += "                                                                                                             1857"

print(spacing)
# Out:
# 2020
#
#
#  9 In days when a man’s profound.
#
#
#     8 I open office, smiles.
#
#
#         7 A few, with pride to the road.
#
#
#              6 They used to problem.
#
#
#                 5 The finishes his hair.
#
#
#                    4 I wish, as the noise.
#
#
#                        3 Sometimes thine ardent loans.
#
#
#                            2 Better than in the car.
#
#
#                               1 “Well, you have a hard look.
#
#
#                                                                                                              1857

# %%
model_cls = markovify.Text if level == "word" else SentencesByChar
gen_a = model_cls(text_a, state_size=order)
gen_b = model_cls(text_b, state_size=order)
gen_combo_1 = markovify.combine([gen_a, gen_b], weight_1)
gen_combo_2 = markovify.combine([gen_a, gen_b], weight_2)
gen_combo_3 = markovify.combine([gen_a, gen_b], weight_3)
gen_combo_4 = markovify.combine([gen_a, gen_b], weight_4)
gen_combo_5 = markovify.combine([gen_a, gen_b], weight_5)
gen_combo_6 = markovify.combine([gen_a, gen_b], weight_6)
gen_combo_7 = markovify.combine([gen_a, gen_b], weight_7)
gen_combo_8 = markovify.combine([gen_a, gen_b], weight_8)
gen_combo_9 = markovify.combine([gen_a, gen_b], weight_9)
for i in range(output_n):
    spacing = ""
    spacing += "2020"
    spacing += "\n"
    spacing += "\n\n"
    spacing += " " + "9 " + gen_combo_9.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "    " + "8 " + gen_combo_8.make_short_sentence(50)
    spacing += "\n"  
    spacing += "\n\n"
    spacing += "        " + "7 " + gen_combo_7.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "             " + "6 " + gen_combo_6.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "                " + "5 " + gen_combo_5.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "                   " + "4 " + gen_combo_4.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "                       " + "3 " + gen_combo_3.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "                           " + "2 " + gen_combo_2.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "                              " + "1 " + gen_combo_1.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n" 
    spacing += "                                                                                                             1857"

print(spacing)
# Out:
# 2020
#
#
#  9 Because he is closed.
#
#
#     8 He laces his shoes.
#
#
#         7 Because as I was home.
#
#
#              6 I do not expectations start.
#
#
#                 5 “Yes, my mother dies.
#
#
#                    4 I feel her eyes there.
#
#
#                        3 A black girl is gold, and we fall.
#
#
#                            2 The Death around the lone.
#
#
#                               1 I really makeup of tears!
#
#
#                                                                                                              1857

# %%
model_cls = markovify.Text if level == "word" else SentencesByChar
gen_a = model_cls(text_a, state_size=order)
gen_b = model_cls(text_b, state_size=order)
gen_combo_1 = markovify.combine([gen_a, gen_b], weight_1)
gen_combo_2 = markovify.combine([gen_a, gen_b], weight_2)
gen_combo_3 = markovify.combine([gen_a, gen_b], weight_3)
gen_combo_4 = markovify.combine([gen_a, gen_b], weight_4)
gen_combo_5 = markovify.combine([gen_a, gen_b], weight_5)
gen_combo_6 = markovify.combine([gen_a, gen_b], weight_6)
gen_combo_7 = markovify.combine([gen_a, gen_b], weight_7)
gen_combo_8 = markovify.combine([gen_a, gen_b], weight_8)
gen_combo_9 = markovify.combine([gen_a, gen_b], weight_9)
for i in range(output_n):
    spacing = ""
    spacing += "2020"
    spacing += "\n"
    spacing += "\n\n"
    spacing += " " + "9 " + gen_combo_9.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "    " + "8 " + gen_combo_8.make_short_sentence(50)
    spacing += "\n"  
    spacing += "\n\n"
    spacing += "        " + "7 " + gen_combo_7.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "             " + "6 " + gen_combo_6.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "                " + "5 " + gen_combo_5.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "                   " + "4 " + gen_combo_4.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "                       " + "3 " + gen_combo_3.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "                           " + "2 " + gen_combo_2.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "                              " + "1 " + gen_combo_1.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n" 
    spacing += "                                                                                                             1857"

print(spacing)
# Out:
# 2020
#
#
#  9 Sticking clean clothes.
#
#
#     8 I assure her boots.
#
#
#         7 I’ve already to die.
#
#
#              6 That’s good audience.
#
#
#                 5 Then she lead on the result.
#
#
#                    4 Are you ever lovers and says it, it’s clear.
#
#
#                        3 A paper all over an heart is a smell.
#
#
#                            2 It’s clear and pens.
#
#
#                               1 Far more than in the mist.
#
#
#                                                                                                              1857

# %%
model_cls = markovify.Text if level == "word" else SentencesByChar
gen_a = model_cls(text_a, state_size=order)
gen_b = model_cls(text_b, state_size=order)
gen_combo_1 = markovify.combine([gen_a, gen_b], weight_1)
gen_combo_2 = markovify.combine([gen_a, gen_b], weight_2)
gen_combo_3 = markovify.combine([gen_a, gen_b], weight_3)
gen_combo_4 = markovify.combine([gen_a, gen_b], weight_4)
gen_combo_5 = markovify.combine([gen_a, gen_b], weight_5)
gen_combo_6 = markovify.combine([gen_a, gen_b], weight_6)
gen_combo_7 = markovify.combine([gen_a, gen_b], weight_7)
gen_combo_8 = markovify.combine([gen_a, gen_b], weight_8)
gen_combo_9 = markovify.combine([gen_a, gen_b], weight_9)
for i in range(output_n):
    spacing = ""
    spacing += "2020"
    spacing += "\n"
    spacing += "\n\n"
    spacing += " " + "9 " + gen_combo_9.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "    " + "8 " + gen_combo_8.make_short_sentence(50)
    spacing += "\n"  
    spacing += "\n\n"
    spacing += "        " + "7 " + gen_combo_7.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "             " + "6 " + gen_combo_6.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "                " + "5 " + gen_combo_5.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "                   " + "4 " + gen_combo_4.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "                       " + "3 " + gen_combo_3.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "                           " + "2 " + gen_combo_2.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n"
    spacing += "                              " + "1 " + gen_combo_1.make_short_sentence(50)
    spacing += "\n"
    spacing += "\n\n" 
    spacing += "                                                                                                             1857"

print(spacing)
# Out:
# 2020
#
#
#  9 All one to stop.
#
#
#     8 I initial sketchbook.
#
#
#         7 You are a few weeks away.
#
#
#              6 I did not see you and he did not feel less trite.
#
#
#                 5 Akila holds herself into Akila.
#
#
#                    4 All one to start.
#
#
#                        3 So long the sort of audience.
#
#
#                            2 “Are the lone.
#
#
#                               1 Eric tries to be what happened.
#
#
#                                                                                                              1857
